# %%
import sys
import os
import colorsys

import numpy as np
import matplotlib.pyplot as plt
import pycocotools.mask as rletools

from PIL import Image
from multiprocessing import Pool
from mots_tools.mots_common.io import load_sequences, load_seqmap
from functools import partial
from subprocess import call

# %%
# adapted from https://github.com/matterport/Mask_RCNN/blob/master/mrcnn/visualize.py
def generate_colors():
  """
  Generate random colors.
  To get visually distinct colors, generate them in HSV space then
  convert to RGB.
  """
  N = 30
  brightness = 0.7
  hsv = [(i / N, 1, brightness) for i in range(N)]
  colors = list(map(lambda c: colorsys.hsv_to_rgb(*c), hsv))
  perm = [15, 13, 25, 12, 19, 8, 22, 24, 29, 17, 28, 20, 2, 27, 11, 26, 21, 4, 3, 18, 9, 5, 14, 1, 16, 0, 23, 7, 6, 10]
  colors = [colors[idx] for idx in perm]
  return colors


# from https://github.com/matterport/Mask_RCNN/blob/master/mrcnn/visualize.py
def apply_mask(image, mask, color, alpha=0.5):
  """Apply the given mask to the image.
  """
  for c in range(3):
    image[:, :, c] = np.where(mask == 1,
                              image[:, :, c] * (1 - alpha) + alpha * color[c],
                              image[:, :, c])
  return image


def process_sequence(seq_id, tracks_folder, img_folder, output_folder, max_frames, draw_boxes=False,
                     create_video=True):
  print("Processing sequence", seq_id)
  os.makedirs(output_folder + "/" + seq_id, exist_ok=True)
  tracks = load_sequences(tracks_folder, [seq_id])[seq_id]
  max_frames_seq = max_frames[seq_id]
  visualize_sequences(seq_id, tracks, max_frames_seq, img_folder, output_folder, draw_boxes, create_video)


def visualize_sequences(seq_id, tracks, max_frames_seq, img_folder, output_folder, draw_boxes=False, create_video=True):
  colors = generate_colors()
  dpi = 100.0
  frames_with_annotations = [frame for frame in tracks.keys() if len(tracks[frame]) > 0]
  img_sizes = next(iter(tracks[frames_with_annotations[0]])).mask["size"]
  for t in range(max_frames_seq + 1):
    print("Processing frame", t)
    filename_t = img_folder + "/" + seq_id + "/%06d" % t
    if os.path.exists(filename_t + ".png"):
      filename_t = filename_t + ".png"
    elif os.path.exists(filename_t + ".jpg"):
      filename_t = filename_t + ".jpg"
    else:
      print("Image file not found for " + filename_t + ".png/.jpg, continuing...")
      continue
    img = np.array(Image.open(filename_t), dtype="float32") / 255
    fig = plt.figure()
    fig.set_size_inches(img_sizes[1] / dpi, img_sizes[0] / dpi, forward=True)
    fig.subplots_adjust(left=0, bottom=0, right=1, top=1, wspace=None, hspace=None)
    ax = fig.subplots()
    ax.set_axis_off()

    if t in tracks:
      for obj in tracks[t]:
        color = colors[obj.track_id % len(colors)]
        if obj.class_id == 1:
          category_name = "Car"
        elif obj.class_id == 2:
          category_name = "Pedestrian"
        else:
          category_name = "Ignore"
          color = (0.7, 0.7, 0.7)
        if obj.class_id == 1 or obj.class_id == 2:  # Don't show boxes or ids for ignore regions
          x, y, w, h = rletools.toBbox(obj.mask)
          if draw_boxes:
            import matplotlib.patches as patches
            rect = patches.Rectangle((x, y), w, h, linewidth=1,
                                     edgecolor=color, facecolor='none', alpha=1.0)
            ax.add_patch(rect)
          category_name += ":" + str(obj.track_id)
          ax.annotate(category_name, (x + 0.5 * w, y + 0.5 * h), color=color, weight='bold',
                      fontsize=7, ha='center', va='center', alpha=1.0)
        binary_mask = rletools.decode(obj.mask)
        apply_mask(img, binary_mask, color)

    ax.imshow(img)
    fig.savefig(output_folder + "/" + seq_id + "/%06d" % t + ".jpg")
    plt.close(fig)
  if create_video:
    os.chdir(output_folder + "/" + seq_id)
    call(["ffmpeg", "-framerate", "10", "-y", "-i", "%06d.jpg", "-c:v", "libx264", "-profile:v", "high", "-crf", "20",
          "-pix_fmt", "yuv420p", "-vf", "pad=\'width=ceil(iw/2)*2:height=ceil(ih/2)*2\'", "output.mp4"])

# %%
tracks_folder = './kitti-mots/instances_txt'
img_folder = './kitti-mots/data_tracking_image_2/training/image_02/'
output_folder = './outputs'
seqmap_filename = './kitti-mots/sequence_map.txt'

seqmap, max_frames = load_seqmap(seqmap_filename)
process_sequence_part = partial(process_sequence, max_frames=max_frames,
                              tracks_folder=tracks_folder, img_folder=img_folder, output_folder=output_folder)

with Pool(70) as pool:
    pool.map(process_sequence_part, seqmap)
    #for seq in seqmap:
    #  process_sequence_part(seq)
# Out:
# Loading seqmap...
# Processing sequenceProcessing sequenceProcessing sequenceProcessing sequenceProcessing sequenceProcessing sequenceProcessing sequenceProcessing sequence Processing sequence Processing sequence Processing sequence   Processing sequence0005  00120009 0011  00000001
# 0003
# 0019
#
# 0004
#
# 001500170020
# Loading sequenceLoading sequence
#
# Loading sequenceLoading sequence
# Loading sequenceLoading sequence
#
# Loading sequence   Loading sequenceLoading sequence Loading sequence   0012Loading sequenceLoading sequence00050009  0011 000100000004
#
# 00030019
# 0015
#
# 0017
#
# 0020
#
#
#
#
# Processing frame 0
# Processing frameProcessing frame  00
#
# Processing frameProcessing frame  0Processing frame0
#
# 0
# Processing frame 0
# Processing frame 0
# Processing frame 0
# Processing frame 0
# Processing frame 1
# Processing frame Processing frame1
# 1
# Processing frame 1Processing frame
#  0
# Processing frame 1
# Processing frameProcessing frame  11
# Processing frame
#  0
# Processing frame 2
# Processing frame 2Processing frame
#  2
# Processing frame 1
# Processing frame 2
# Processing frame 2
# Processing frame 1
# Processing frame 3
# Processing frameProcessing frame Processing frame3
# 32
#
# Processing frame 2
# Processing frame Processing frame3
# 2
# Processing frame 1
# Processing frame 1
# Processing frame 3
# Processing frame 4
# Processing frame Processing frame4
# 4
# Processing frameProcessing frame 4
# 3
# Processing frame 2
# Processing frame 1Processing frame
#  3
# Processing frame 2
# Processing frame 5
# Processing frame 4
# Processing frame 5
# Processing frame 5
# Processing frame Processing frame 45
#
# Processing frame 2
# Processing frame 6
# Processing frame 3Processing frame
# 4
# Processing frame 3
# Processing frame 5
# Processing frame 6
# Processing frame 6
# Processing frame 6
# Processing frameProcessing frame  5
# 7
# Processing frame 2
# Processing frameProcessing frame  45
#
# Processing frame 6
# Processing frame 7
# Processing frameProcessing frame  7
# Processing frame8Processing frame  Processing frame
# 67
#
# 4
# Processing frame Processing frame5
# 6
# Processing frame 9
# Processing frame Processing frame8
#  7
# Processing frame 3
# Processing frame 8
# Processing frame 7
# Processing frame 8
# Processing frameProcessing frame  67
#
# Processing frame 5
# Processing frame 10
# Processing frame 9
# Processing frame 8
# Processing frame 3
# Processing frame Processing frame9
# 9
# Processing frame 8
# Processing frame 11
# Processing frameProcessing frame  78
#
# Processing frame 10Processing frame
#  4
# Processing frame 9
# Processing frame 10Processing frame
#  10Processing frame
#  6
# Processing frame 9
# Processing frame 12
# Processing frame 4
# Processing frame 9
# Processing frame 8
# Processing frame 11
# Processing frame 10Processing frame
#  11
# Processing frame 11
# Processing frame 13
# Processing frame 10
# Processing frame 7
# Processing frame 10
# Processing frameProcessing frame  129
#
# Processing frame 14
# Processing frame 12
# Processing frame 11
# Processing frame 5
# Processing frameProcessing frame  12
# 11
# Processing frame 11
# Processing frame 5
# Processing frame 15
# Processing frame 13
# Processing frame 13
# Processing frame 8
# Processing frame 12
# Processing frame 12
# Processing frame 16
# Processing frame 14
# Processing frame 13
# Processing frame 17
# Processing frame 13
# Processing frame 14
# Processing frame 15
# Processing frame 12
# Processing frame 14
# Processing frame 18
# Processing frame 14
# Processing frame 15
# Processing frame 16
# Processing frame 13
# Processing frame 19
# Processing frameProcessing frame  1510
#
# Processing frame 9
# Processing frame 13
# Processing frame 15
# Processing frame 16
# Processing frame 17
# Processing frame 6
# Processing frame Processing frame14
#  20
# Processing frame 16
# Processing frame 17Processing frame
#  14
# Processing frame 16
# Processing frame 18
# Processing frame 21
# Processing frame 15
# Processing frame 10
# Processing frame 6
# Processing frame 17
# Processing frame 15
# Processing frame 18
# Processing frameProcessing frame  722
#
# Processing frame 17
# Processing frame 19
# Processing frame 11
# Processing frame 16
# Processing frame 18
# Processing frame 16
# Processing frame 19
# Processing frame 11
# Processing frame 7
# Processing frame 12
# Processing frame 17
# Processing frame 8
# Processing frame 19
# Processing frame 23
# Processing frame 17
# Processing frame 20
# Processing frame Processing frame20
# 18
# Processing frame 13
# Processing frame Processing frame12
# 18
# Processing frame 24
# Processing frame 8
# Processing frame 20
# Processing frame 9
# Processing frame 25
# Processing frame 19
# Processing frame 19
# Processing frame 21
# Processing frame 9
# Processing frame 13
# Processing frame 21
# Processing frame 26
# Processing frame 20
# Processing frame 14
# Processing frame 27
# Processing frame 18
# Processing frame 21
# Processing frame 22
# Processing frame 19
# Processing frame 22
# Processing frame 28
# Processing frame 20
# Processing frame 23
# Processing frame 14
# Processing frame 22
# Processing frame 21
# Processing frame 29
# Processing frame Processing frame10
# 20
# Processing frame 24
# Processing frame Processing frame 2310
#
# Processing frame 30
# Processing frame Processing frame11
# 21
# Processing frame 23
# Processing frame Processing frame21 22
#
# Processing frame 25
# Processing frame 31
# Processing frame 15
# Processing frame 24
# Processing frame 22Processing frame
#  Processing frame32
# 11
# Processing frame 22
# Processing frame 12Processing frame
#  26
# Processing frame 24
# Processing frame 33
# Processing frame 16
# Processing frame 25
# Processing frame 23
# Processing frame 23
# Processing frame 27
# Processing frame 34
# Processing frame 13
# Processing frame 12
# Processing frame 25
# Processing frame 23
# Processing frame 26
# Processing frame 35
# Processing frame 24
# Processing frame 24
# Processing frame 24
# Processing frameProcessing frame  1728
#
# Processing frame 14
# Processing frame Processing frame26
# 15
# Processing frame 36
# Processing frame 13
# Processing frame 27
# Processing frame 16
# Processing frame 37
# Processing frame 27
# Processing frame 25
# Processing frame 25
# Processing frame 25
# Processing frame 38
# Processing frame 17
# Processing frame 15
# Processing frame 28
# Processing frame 18
# Processing frame 14
# Processing frame 28
# Processing frame 26
# Processing frame 18
# Processing frame 39
# Processing frame 26
# Processing frame 26
# Processing frame 16
# Processing frame 29
# Processing frame 27
# Processing frame 19
# Processing frame 15
# Processing frame 40Processing frame
#  29
# Processing frame 19
# Processing frame 27
# Processing frame 27
# Processing frame 28
# Processing frame 41
# Processing frame 20
# Processing frame 30
# Processing frame 20
# Processing frame 30
# Processing frame 28
# Processing frame 16
# Processing frameProcessing frame  2817
#
# Processing frame 3
# Processing frameProcessing frame  2921
#
# Processing frame 31
# Processing frame 29
# Processing frame 31
# Processing frame 30
# Processing frame 22
# Processing frame 21
# Processing frame 30
# Processing frameProcessing frameProcessing frameProcessing frameProcessing frameProcessing frameProcessing frame  Processing frame   17  418Processing frame 2229
# 3123
#
#  29
# Processing frame
#
#
# 32
#
# 32
# Processing frame 31
# Processing frame Processing frame24
# 32
# Processing frameProcessing frame  1830
#
# Processing frame 30
# Processing frame 23
# Processing frame 25
# Processing frame 33
# Processing frame 33Processing frame
#  5
# Processing frame 32
# Processing frame 19
# Processing frame 31
# Processing frame 31
# Processing frame 26
# Processing frame 34
# Processing frame 33
# Processing frame 19
# Processing frameProcessing frame  246
#
# Processing frame 34
# Processing frame 20
# Processing frame 32
# Processing frame 32
# Processing frame 27
# Processing frame 35
# Processing frame 34
# Processing frame 20
# Processing frame 7
# Processing frame 33
# Processing frameProcessing frame  3528
#
# Processing frame 21
# Processing frame 34
# Processing frame 36
# Processing frameProcessing frame  3336
#
# Processing frame 29
# Processing frameProcessing frame  2535
#
# Processing frame 21
# Processing frame 35
# Processing frame 8
# Processing frame Processing frame22
# 37
# Processing frameProcessing frame  3734
#
# Processing frame 30
# Processing frame 36
# Processing frame 26
# Processing frame 9
# Processing frameProcessing frame  38
# 38
# Processing frameProcessing frameProcessing frameProcessing frame   Processing frame Processing frameProcessing frame35223631 Processing frame
#
# Processing frame
#
# 10 2327
# 37
#
# 33
#
# Processing frame 39
# Processing frameProcessing frameProcessing frame  38 32
# 39
#
# Processing frame 11
# Processing frame Processing frame37
# 28
# Processing frame Processing frame24 23
#
# Processing frameProcessing frame  3933
#
# Processing frame 40
# Processing frame 34Processing frame
#  36
# Processing frame Processing frame29
# 41
# Processing frameProcessing frame  2540
#
# Processing frame 12
# Processing frame Processing frame38
# 24Processing frame
#  40
# Processing frame Processing frame42
# 37
# Processing frame 35
# Processing frame 41Processing frame
#  30
# Processing frame 26
# Processing frame 41
# Processing frame 43
# Processing frame 13
# Processing frame 38
# Processing frame 36
# Processing frame 39Processing frame
#  25
# Processing frame 42
# Processing frame 42
# Processing frame 44
# Processing frame 31
# Processing frame 27
# Processing frame 39
# Processing frame 37
# Processing frame 14
# Processing frame 45
# Processing frame 40
# Processing frame 43
# Processing frame 38
# Processing frame 44
# Processing frame 28
# Processing frame 41
# Processing frame 39Processing frame
#  43
# Processing frame 46
# Processing frame 15
# Processing frameProcessing frame  2632
#
# Processing frame 40
# Processing frame 45
# Processing frame 42
# Processing frame 40
# Processing frame 44
# Processing frame 47
# Processing frame 29
# Processing frame 34
# Processing frame 16
# Processing frame 46
# Processing frame 41
# Processing frame Processing frame33
# 43
# Processing frameProcessing frame  2748
#
# Processing frame Processing frame35
# 45
# Processing frame 30
# Processing frame 47
# Processing frame 17Processing frame
#  42
# Processing frame 44
# Processing frame 34
# Processing frame 49
# Processing frame 36Processing frame
#  46
# Processing frameProcessing frame  4828
#
# Processing frame 31
# Processing frame 43
# Processing frame 45
# Processing frame 50
# Processing frame 47Processing frame
#  44
# Processing frame 42
# Processing frame 49
# Processing frame 32
# Processing frame 51
# Processing frame 18
# Processing frame 43
# Processing frame Processing frame45
# 37
# Processing frame Processing frame48
#  35
# Processing frame 52
# Processing frame 29Processing frame
#  50
# Processing frame Processing frame33
# 44
# Processing frame 46
# Processing frame 19
# Processing frame 51
# Processing frameProcessing frame Processing frame 53
# 3845
#
# Processing frame 49
# Processing frame 47
# Processing frame 36
# Processing frame 30
# Processing frame 34
# Processing frame 52
# Processing frame 54
# Processing frame 39
# Processing frame 20
# Processing frame 46
# Processing frame 48
# Processing frame 53Processing frame
#  35
# Processing frame 50
# Processing frame 37
# Processing frame 40
# Processing frame 31
# Processing frame 55
# Processing frame 49Processing frame
#  41
# Processing frame 36
# Processing frame 38
# Processing frame 50
# Processing frame 41
# Processing frame Processing frame32
# 47
# Processing frame 54
# Processing frame 37
# Processing frame 56
# Processing frame 51
# Processing frame 39Processing frame
#  48
# Processing frame 42
# Processing frame 42
# Processing frame 21
# Processing frame 33
# Processing frame 38
# Processing frame 55
# Processing frame 49
# Processing frame 52
# Processing frame 43
# Processing frame 40
# Processing frameProcessing frame  5743
#
# Processing frame 50
# Processing frame 56
# Processing frame 39
# Processing frame 22
# Processing frame 34
# Processing frame 51
# Processing frame 53
# Processing frame 40
# Processing frameProcessing frame  4144
#
# Processing frameProcessing frame  4435
#
# Processing frame 54
# Processing frame 41
# Processing frame 52
# Processing frame 45Processing frame
#  57
# Processing frame 51
# Processing frame 55
# Processing frame 23
# Processing frame 42
# Processing frame 36Processing frame
#  45
# Processing frame 53
# Processing frame 42
# Processing frame 46
# Processing frame 58
# Processing frame 56
# Processing frame 58
# Processing frame 54
# Processing frame 24
# Processing frame 52
# Processing frame 43
# Processing frame 59
# Processing frame 43
# Processing frameProcessing frame  4637
#
# Processing frame 57
# Processing frame 59
# Processing frame 47
# Processing frame 25
# Processing frame 44
# Processing frame 60
# Processing frame 58
# Processing frame 38Processing frame
# Processing frame  4748
#
# Processing frame 44
# Processing frameProcessing frame  5960
#
# Processing frame 53
# Processing frame 61
# Processing frame 45
# Processing frame 26
# Processing frame 49
# Processing frame 60
# Processing frameProcessing frame Processing frame61 48
#  39
#
# Processing frame 45
# Processing frame 62
# Processing frame 54
# Processing frame 27
# Processing frame 46
# Processing frame 61Processing frame
#  50
# Processing frame 62
# Processing frame 46
# Processing frame 49Processing frame
#  40
# Processing frame 28
# Processing frame 63
# Processing frame 51Processing frame
#  62
# Processing frame 55
# Processing frame 47
# Processing frame 63
# Processing frame 55
# Processing frame 47
# Processing frame 52
# Processing frame 64
# Processing frame Processing frame29
#  63
# Processing frame 50
# Processing frame 64
# Processing frame 41
# Processing frame 56
# Processing frame 56
# Processing frame 48
# Processing frame Processing frame53
# 64
# Processing frame 57
# Processing frame 30
# Processing frame 65
# Processing frame 51
# Processing frame 65
# Processing frame Processing frame57Processing frame
#   54
# 42
# Processing frame 49
# Processing frame 58Processing frame
#  65
# Processing frame 66
# Processing frame Processing frame66
# 31
# Processing frame 66
# Processing frame Processing frame58
# 55
# Processing frame 52
# Processing frame 67
# Processing frame 67
# Processing frame 50
# Processing frame 43
# Processing frame 67Processing frame
#  32
# Processing frame 56
# Processing frame 68
# Processing frame 59
# Processing frame 68
# Processing frame 53
# Processing frame Processing frame68
# 48
# Processing frame 33Processing frame
#  51
# Processing frame 44
# Processing frame 69
# Processing frame 57
# Processing frame 69
# Processing frame 69
# Processing frame 49
# Processing frame 59Processing frame
#  52
# Processing frame 54
# Processing frame 70
# Processing frame 34
# Processing frame 58
# Processing frame 70
# Processing frame 60
# Processing frame 70
# Processing frame 45
# Processing frame 50
# Processing frame 53
# Processing frame 59Processing frame
#  71
# Processing frame 71
# Processing frame 35
# Processing frame 55
# Processing frame 61
# Processing frame 71
# Processing frame 51
# Processing frameProcessing frame  4672
#
# Processing frame 72
# Processing frame 54
# Processing frame 72
# Processing frameProcessing frame  3660
#
# Processing frame 62
# Processing frame 52
# Processing frame 73
# Processing frame 56
# Processing frame 63
# Processing frame 47
# Processing frame 73
# Processing frame Processing frame73
# 55
# Processing frame 60
# Processing frame 37
# Processing frame 53
# Processing frame 64
# Processing frame Processing frame74
# 74
# Processing frame 74
# Processing frameProcessing frame  48
# 56
# Processing frame 75Processing frame
#  65Processing frame
#  61
# Processing frame 61
# Processing frame 57
# Processing frame Processing frame75
# 38
# Processing frame 75
# Processing frame 66
# Processing frame 62
# Processing frame 76
# Processing frame 49
# Processing frame 58
# Processing frame 39
# Processing frame 77
# Processing frame 57
# Processing frame 62
# Processing frame 59
# Processing frame 54
# Processing frame 76
# Processing frame Processing frame58
# 40
# Processing frame 78
# Processing frame Processing frame63
# 67
# Processing frame 50
# Processing frame 60
# Processing frame 55
# Processing frame 76
# Processing frame 63
# Processing frame 79
# Processing frame 68
# Processing frame 59
# Processing frame 41
# Processing frame 64
# Processing frameProcessing frameProcessing frame   77
# 6456
#
# Processing frame 61
# Processing frame 69
# Processing frame 80
# Processing frame 77
# Processing frame 65
# Processing frame 60
# Processing frame 51
# Processing frame 70
# Processing frame 78
# Processing frame 78
# Processing frame 65
# Processing frame 81
# Processing frame 66
# Processing frame 62
# Processing frame 61
# Processing frame 71
# Processing frame 46
# Processing frame 57
# Processing frame 79
# Processing frame 79
# Processing frame 82
# Processing frame 52
# Processing frame 67
# Processing frame Processing frame72
# 47
# Processing frame 63
# Processing frame 80
# Processing frame 58
# Processing frame 62
# Processing frame 73Processing frame
#  Processing frame68
# 80
# Processing frame 42Processing frame
#  83
# Processing frame 53
# Processing frame 48
# Processing frame 81
# Processing frame 74
# Processing frame 69
# Processing frame 81
# Processing frame 63
# Processing frame 59
# Processing frame 43
# Processing frame 64
# Processing frameProcessing frame  5484
#
# Processing frame 75
# Processing frame 70
# Processing frame 49
# Processing frame 82
# Processing frame 60
# Processing frame 82
# Processing frameProcessing frame  4464
#
# Processing frame 65
# Processing frameProcessing frame  8583
#
# Processing frame 71
# Processing frame 55
# Processing frame 76
# Processing frame Processing frame84
# 50
# Processing frame 72Processing frame
#  61
# Processing frame 83
# Processing frame Processing frame86
#  45
# Processing frame 66
# Processing frameProcessing frame  6577
#
# Processing frame 56
# Processing frame 51
# Processing frame 84
# Processing frame 78
# Processing frame 85
# Processing frame 73
# Processing frame 46
# Processing frame 62
# Processing frame 87
# Processing frame 52
# Processing frame 79
# Processing frame 66Processing frame
#  Processing frame67
# 85
# Processing frame 86
# Processing frame 74
# Processing frame 57
# Processing frame 47
# Processing frame 63
# Processing frame 87
# Processing frame 88
# Processing frame 75
# Processing frame 80
# Processing frame 53
# Processing frame 48
# Processing frame 67
# Processing frame 68
# Processing frame Processing frame58
# 88
# Processing frame Processing frame64
# 86
# Processing frame 81Processing frame
#  76
# Processing frame 89
# Processing frame 54
# Processing frame 49
# Processing frameProcessing frame  8982
#
# Processing frame 87
# Processing frame 77
# Processing frame 68
# Processing frame 65
# Processing frame 55
# Processing frame 59
# Processing frame 69
# Processing frame 90
# Processing frame 83
# Processing frame 90
# Processing frame 78
# Processing frame 50
# Processing frame 88
# Processing frame 69
# Processing frame Processing frameProcessing frame79
# 8491
#
# Processing frame 66
# Processing frame 56
# Processing frame 91
# Processing frame 60
# Processing frame 70
# Processing frame 85
# Processing frame 80
# Processing frameProcessing frame  8992
#
# Processing frame 51
# Processing frame 67
# Processing frame 57
# Processing frame 70
# Processing frame 92
# Processing frame 81
# Processing frame 93
# Processing frame 90
# Processing frame 61
# Processing frame 71
# Processing frame 82
# Processing frame 94
# Processing frame 93
# Processing frame 86
# Processing frame 68
# Processing frame 91
# Processing frame 62
# Processing frame 52
# Processing frame 58
# Processing frame 87
# Processing frame 83
# Processing frame 94
# Processing frame 95
# Processing frame 69
# Processing frame Processing frame92
# 71
# Processing frame 88
# Processing frame 84
# Processing frame 72
# Processing frame 96
# Processing frame 63Processing frame
#  59
# Processing frame 53
# Processing frameProcessing frame Processing frame 89 93
#
# 70
# Processing frame 85
# Processing frame 72
# Processing frame 73
# Processing frame 95
# Processing frame 97
# Processing frame 86
# Processing frame 90
# Processing frame60
# Processing frame 94
# Processing frame Processing frame 9854
#
# Processing frame 71Processing frame
#  87
# Processing frame 73Processing frame
#  96
# Processing frame 91
# Processing frame 64
# Processing frame 61
# Processing frame 74
# Processing frame 99
# Processing frame 95Processing frame
# 92Processing frame
#  88
# Processing frame 72
# Processing frame 55
# Processing frame 97Processing frame
# 74
# Processing frame 93
# Processing frame 65
# Processing frame Processing frame62
# 89
# Processing frame 100
# Processing frame 73
# Processing frame 96
# Processing frame 56Processing frame
#  75
# Processing frame 94
# Processing frame 98
# Processing frame 75
# Processing frame 90
# Processing frame 101
# Processing frame Processing frame95
# 63
# Processing frame 74
# Processing frame 66
# Processing frame 97
# Processing frame 57
# Processing frame 91
# Processing frame 99
# Processing frame 76
# Processing frame 76
# Processing frame 102
# Processing frame 96
# Processing frame 98
# Processing frame 92
# Processing frame 75
# Processing frame 64
# Processing frameProcessing frame  5867
#
# Processing frame 100
# Processing frame 77
# Processing frame 93
# Processing frame 77
# Processing frame 99
# Processing frame 97
# Processing frame 103
# Processing frameProcessing frame  10159
#
# Processing frame 76
# Processing frame 68
# Processing frameProcessing frame  9498
#
# Processing frame 66
# Processing frame 100
# Processing frame 65Processing frame
#  78
# Processing frame 104
# Processing frame 60
# Processing frameProcessing frame  10277
#
# Processing frame 99
# Processing frame 95
# Processing frame 101
# Processing frame Processing frame105
# 66
# Processing frame 67
# Processing frame 69
# Processing frame 100
# Processing frame 96
# Processing frame 78
# Processing frame 79
# Processing frame 103
# Processing frame 102
# Processing frame 67Processing frame
#  106
# Processing frame 101
# Processing frame 68
# Processing frame 97
# Processing frame 61
# Processing frame Processing frame79
# 103
# Processing frameProcessing frame  6870
#
# Processing frame 107
# Processing frame 104
# Processing frame 102
# Processing frame 98
# Processing frame 80
# Processing frameProcessing frame  10469
#
# Processing frame 62
# Processing frame 69
# Processing frame 80
# Processing frame 105
# Processing frame 99
# Processing frame 71
# Processing frame 108
# Processing frame 100
# Processing frame Processing frame103
# 106
# Processing frame 70
# Processing frame 81
# Processing frame 101
# Processing frame 63
# Processing frameProcessing frame  105104
#
# Processing frame 72Processing frame
#  Processing frame70
#  109
# Processing frame 81
# Processing frame 107
# Processing frame 71
# Processing frame 102
# Processing frame 105
# Processing frame 82
# Processing frame 106
# Processing frame 110
# Processing frameProcessing frame  10364
#
# Processing frame 72
# Processing frameProcessing frame  71108
#
# Processing frame 73
# Processing frame 82
# Processing frame 111
# Processing frame 83
# Processing frame 106
# Processing frame 73
# Processing frameProcessing frame  104
# 107
# Processing frame 65
# Processing frame 109Processing frame
#  72
# Processing frame 107
# Processing frame 112
# Processing frame 74
# Processing frameProcessing frame  8374
#
# Processing frame 108
# Processing frame 84
# Processing frame 66
# Processing frame 108
# Processing frame 110
# Processing frame 113Processing frame
# 73
# Processing frame 75
# Processing frame 109
# Processing frame 105
# Processing frame 75
# Processing frame 67
# Processing frame 84
# Processing frame 109
# Processing frame 111
# Processing frame 85
# Processing frame 74
# Processing frame 106
# Processing frame 76
# Processing frame 68
# Processing frame 114
# Processing frame 85Processing frame
#  Processing frame86
# 110
# Processing frameProcessing frame  76112
#
# Processing frame 107
# Processing frame 77
# Processing frame 75
# Processing frame 110
# Processing frame 69
# Processing frameProcessing frame  108115
#
# Processing frame 87
# Processing frame 111
# Processing frame 113
# Processing frame 86
# Processing frame 77
# Processing frame 111
# Processing frame 76
# Processing frame 109Processing frame
#  Processing frame116
# 70
# Processing frame 88
# Processing frame 112
# Processing frame 112
# Processing frame 114
# Processing frameProcessing frame  78110
#
# Processing frame 87
# Processing frame 77
# Processing frame 113
# Processing frame Processing frame71
# 117
# Processing frame 89
# Processing frame 113
# Processing frame 111
# Processing frame 115
# Processing frameProcessing frame  88114
# Processing frame
#  118
# Processing frame 79
# Processing frame 114
# Processing frame 112
# Processing frame 72
# Processing frame 115
# Processing frame 119
# Processing frame 90
# Processing frame 78
# Processing frame 116
# Processing frameProcessing frame  89115
#
# Processing frame 113
# Processing frame 73
# Processing frame 116
# Processing frame 80Processing frame
#  120
# Processing frame 91
# Processing frameProcessing frameProcessing frame   79116117
#
#
# Processing frame 114
# Processing frame 90
# Processing frameProcessing frame  74117
#
# Processing frame 117
# Processing frame 115
# Processing frame 121
# Processing frame 118
# Processing frame 92
# Processing frame 80
# Processing frame 118
# Processing frame 81
# Processing frame 91
# Processing frame 75
# Processing frame 116
# Processing frameProcessing frame  118119
#
# Processing frame Processing frame76
# 122
# ffmpeg version 5.1.4-0+deb12u1 Copyright (c) 2000-2023 the FFmpeg developers
#   built with gcc 12 (Debian 12.2.0-14)
#   configuration: --prefix=/usr --extra-version=0+deb12u1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libglslang --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librist --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --disable-sndio --enable-libjxl --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-libplacebo --enable-librav1e --enable-shared
#   libavutil      57. 28.100 / 57. 28.100
#   libavcodec     59. 37.100 / 59. 37.100
#   libavformat    59. 27.100 / 59. 27.100
#   libavdevice    59.  7.100 / 59.  7.100
#   libavfilter     8. 44.100 /  8. 44.100
#   libswscale      6.  7.100 /  6.  7.100
#   libswresample   4.  7.100 /  4.  7.100
#   libpostproc    56.  6.100 / 56.  6.100
# Input #0, image2, from '%06d.jpg':
#   Duration: 00:00:07.80, start: 0.000000, bitrate: N/A
#   Stream #0:0: Video: mjpeg (Baseline), yuvj420p(pc, bt470bg/unknown/unknown), 1242x375 [SAR 100:100 DAR 414:125], 10 fps, 10 tbr, 10 tbn
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [swscaler @ 0x55ed76f06f00] [swscaler @ 0x55ed76f231c0] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed76f06f00] [swscaler @ 0x55ed76f4ec80] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed76f06f00] [swscaler @ 0x55ed76f7a940] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed76f06f00] [swscaler @ 0x55ed76fa6600] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed76f06f00] [swscaler @ 0x55ed76fd1cc0] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed76f06f00] [swscaler @ 0x55ed76ffdb80] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed76f06f00] [swscaler @ 0x55ed77029840] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed76f06f00] [swscaler @ 0x55ed77054f00] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed76f06f00] [swscaler @ 0x55ed77080dc0] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed76f06f00] [swscaler @ 0x55ed770aca80] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed76f06f00] [swscaler @ 0x55ed770d8140] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed76f06f00] [swscaler @ 0x55ed77104000] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed76f06f00] [swscaler @ 0x55ed7712fcc0] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed76f06f00] [swscaler @ 0x55ed7715b380] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed76f06f00] [swscaler @ 0x55ed77187240] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed76f06f00] [swscaler @ 0x55ed771b2f00] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed76f06f00] [swscaler @ 0x55ed771de5c0] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed76f06f00] [swscaler @ 0x55ed7720a6c0] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed76f06f00] [swscaler @ 0x55ed77236380] deprecated pixel format used, make sure you did set range correctly
# Processing frame 119
# Processing frame 81
# Processing frameProcessing frame  11782
#
# Processing frame 93
# Processing frame 92
# Processing frame 120
# Processing frame 119
# Processing frameProcessing frameProcessing frame   12377120
#
#
# Processing frame 118
# [swscaler @ 0x55ed76f06f00] [swscaler @ 0x55ed77262040] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed76f06f00] [swscaler @ 0x55ed7728d700] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed76f06f00] [swscaler @ 0x55ed772b95c0] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed76f06f00] [swscaler @ 0x55ed772e5280] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed76f06f00] [swscaler @ 0x55ed77310f40] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed76f06f00] [swscaler @ 0x55ed7733c600] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed76f06f00] [swscaler @ 0x55ed773684c0] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed76f06f00] [swscaler @ 0x55ed77394180] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed76f06f00] [swscaler @ 0x55ed773bfe40] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed76f06f00] [swscaler @ 0x55ed773eb500] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed76f06f00] [swscaler @ 0x55ed774173c0] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed76f06f00] [swscaler @ 0x55ed77443080] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed76f06f00] [swscaler @ 0x55ed7746ed40] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed76f06f00] [swscaler @ 0x55ed7749a400] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed76f06f00] [swscaler @ 0x55ed774c62c0] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed76f06f00] [swscaler @ 0x55ed774f1f80] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed76f06f00] [swscaler @ 0x55ed7751dc40] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed76f06f00] [swscaler @ 0x55ed77549300] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed76f06f00] [swscaler @ 0x55ed775751c0] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed76f06f00] [swscaler @ 0x55ed775a0e80] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed76f06f00] [swscaler @ 0x55ed775ccb40] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed76f06f00] [swscaler @ 0x55ed775f8200] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed76f06f00] [swscaler @ 0x55ed776240c0] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed76f06f00] [swscaler @ 0x55ed7764fd80] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed76f06f00] [swscaler @ 0x55ed7767ba40] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed76f06f00] [swscaler @ 0x55ed776a7100] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed76f06f00] [swscaler @ 0x55ed776d2fc0] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed76f06f00] [swscaler @ 0x55ed776fec80] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed76f06f00] [swscaler @ 0x55ed7772a940] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed76f06f00] [swscaler @ 0x55ed77756000] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed76f06f00] [swscaler @ 0x55ed77781ec0] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed76f06f00] [swscaler @ 0x55ed777adb80] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed76f06f00] [swscaler @ 0x55ed777d9840] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed76f06f00] [swscaler @ 0x55ed77804f00] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed76f06f00] [swscaler @ 0x55ed77830dc0] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed76f06f00] [swscaler @ 0x55ed7785ca80] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed76f06f00] [swscaler @ 0x55ed77888740] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed76f06f00] [swscaler @ 0x55ed778b3e00] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed76f06f00] [swscaler @ 0x55ed778dfcc0] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed76f06f00] [swscaler @ 0x55ed7790b980] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed76f06f00] [swscaler @ 0x55ed77937640] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed76f06f00] [swscaler @ 0x55ed77962d00] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed76f06f00] [swscaler @ 0x55ed7798ebc0] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed76f06f00] [swscaler @ 0x55ed779ba880] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed76f06f00] [swscaler @ 0x55ed779e6540] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed76f06f00] [swscaler @ 0x55ed77a11c00] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed76f06f00] [swscaler @ 0x55ed77a3dac0] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed76f06f00] [swscaler @ 0x55ed77a69780] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed76f06f00] [swscaler @ 0x55ed77a95440] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed76f06f00] [swscaler @ 0x55ed77ac0b00] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed76f06f00] [swscaler @ 0x55ed77aec9c0] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed76f06f00] [swscaler @ 0x55ed77b18680] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed76f06f00] [swscaler @ 0x55ed77b44340] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed76f06f00] [swscaler @ 0x55ed77b6fa00] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed76f06f00] [swscaler @ 0x55ed77b9b8c0] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed76f06f00] [swscaler @ 0x55ed77bc7580] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed76f06f00] [swscaler @ 0x55ed77bf3240] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed76f06f00] [swscaler @ 0x55ed77c1e900] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed76f06f00] [swscaler @ 0x55ed77c4a7c0] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed76f06f00] [swscaler @ 0x55ed77c76480] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed76f06f00] [swscaler @ 0x55ed77ca2140] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed76f06f00] [swscaler @ 0x55ed77ccd800] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed77cebb40] [swscaler @ 0x55ed76f231c0] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed77cebb40] [swscaler @ 0x55ed76f08fc0] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed77cebb40] [swscaler @ 0x55ed76fc3b00] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed77cebb40] [swscaler @ 0x55ed770c9f80] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed77cebb40] [swscaler @ 0x55ed77047fc0] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed77cebb40] [swscaler @ 0x55ed76f6e0c0] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed77cebb40] [swscaler @ 0x55ed76ff1cc0] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed77cebb40] [swscaler @ 0x55ed76f9ae40] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed77cebb40] [swscaler @ 0x55ed7701e680] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed77cebb40] [swscaler @ 0x55ed77076600] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed77cebb40] [swscaler @ 0x55ed770a2780] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed77cebb40] [swscaler @ 0x55ed770f6100] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed77cebb40] [swscaler @ 0x55ed77122200] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed77cebb40] [swscaler @ 0x55ed7714dec0] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed77cebb40] [swscaler @ 0x55ed772abc80] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed77cebb40] [swscaler @ 0x55ed772d7540] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed77cebb40] [swscaler @ 0x55ed77303400] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed77cebb40] [swscaler @ 0x55ed7732f0c0] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed77cebb40] [swscaler @ 0x55ed77179900] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed77cebb40] [swscaler @ 0x55ed771a57c0] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed77cebb40] [swscaler @ 0x55ed771d0e80] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed77cebb40] [swscaler @ 0x55ed771fcd40] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed77cebb40] [swscaler @ 0x55ed77228a00] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed77cebb40] [swscaler @ 0x55ed772540c0] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed77cebb40] [swscaler @ 0x55ed7727ff80] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed77cebb40] [swscaler @ 0x55ed7735ab80] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed77cebb40] [swscaler @ 0x55ed77386a40] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed77cebb40] [swscaler @ 0x55ed773b2100] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed77cebb40] [swscaler @ 0x55ed773de200] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed77cebb40] [swscaler @ 0x55ed77409ec0] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed77cebb40] [swscaler @ 0x55ed77435580] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed77cebb40] [swscaler @ 0x55ed77461440] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed77cebb40] [swscaler @ 0x55ed7748d100] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed77cebb40] [swscaler @ 0x55ed774b8dc0] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed77cebb40] [swscaler @ 0x55ed774e4480] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed77cebb40] [swscaler @ 0x55ed77510580] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed77cebb40] [swscaler @ 0x55ed7753c240] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed77cebb40] [swscaler @ 0x55ed77567900] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed77cebb40] [swscaler @ 0x55ed775937c0] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed77cebb40] [swscaler @ 0x55ed775bf480] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed77cebb40] [swscaler @ 0x55ed775eb140] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed77cebb40] [swscaler @ 0x55ed77616800] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed77cebb40] [swscaler @ 0x55ed77642900] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed77cebb40] [swscaler @ 0x55ed7766e5c0] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed77cebb40] [swscaler @ 0x55ed7769a280] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed77cebb40] [swscaler @ 0x55ed776c5940] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed77cebb40] [swscaler @ 0x55ed776f1800] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed77cebb40] [swscaler @ 0x55ed7771d4c0] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed77cebb40] [swscaler @ 0x55ed77749180] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed77cebb40] [swscaler @ 0x55ed77774840] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed77cebb40] [swscaler @ 0x55ed777a0700] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed77cebb40] [swscaler @ 0x55ed777cc3c0] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed77cebb40] [swscaler @ 0x55ed777f8080] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed77cebb40] [swscaler @ 0x55ed77823740] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed77cebb40] [swscaler @ 0x55ed7784f600] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed77cebb40] [swscaler @ 0x55ed7787b2c0] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed77cebb40] [swscaler @ 0x55ed778a6f80] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed77cebb40] [swscaler @ 0x55ed778d2640] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed77cebb40] [swscaler @ 0x55ed778fe500] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed77cebb40] [swscaler @ 0x55ed7792a1c0] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed77cebb40] [swscaler @ 0x55ed77955e80] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed77cebb40] [swscaler @ 0x55ed77981540] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed77cebb40] [swscaler @ 0x55ed779ad400] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed77cebb40] [swscaler @ 0x55ed779d90c0] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed77cebb40] [swscaler @ 0x55ed77a04d80] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed77cebb40] [swscaler @ 0x55ed77a30440] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed77cebb40] [swscaler @ 0x55ed77a5c300] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed77cebb40] [swscaler @ 0x55ed77a87fc0] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed77cebb40] [swscaler @ 0x55ed77ab3c80] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed77cebb40] [swscaler @ 0x55ed77adf340] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed77cebb40] [swscaler @ 0x55ed77b0b200] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed77cebb40] [swscaler @ 0x55ed77b36ec0] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed77cebb40] [swscaler @ 0x55ed77b62b80] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed77cebb40] [swscaler @ 0x55ed77b8e240] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed77cebb40] [swscaler @ 0x55ed77bba100] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed77cebb40] [swscaler @ 0x55ed77be5dc0] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed77cebb40] [swscaler @ 0x55ed77c11a80] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed77cebb40] [swscaler @ 0x55ed77c3d140] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed77cebb40] [swscaler @ 0x55ed77c69000] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed77cebb40] [swscaler @ 0x55ed77c94cc0] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed77cebb40] [swscaler @ 0x55ed77cc0980] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed77cebb40] [swscaler @ 0x55ed77086e00] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed77cebb40] [swscaler @ 0x55ed76f231c0] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed77cebb40] [swscaler @ 0x55ed76f06f00] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed77cebb40] [swscaler @ 0x55ed770c9f80] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed77cebb40] [swscaler @ 0x55ed77048e00] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed77cebb40] [swscaler @ 0x55ed76f4b6c0] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed77cebb40] [swscaler @ 0x55ed76fa4ec0] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed77cebb40] [swscaler @ 0x55ed76fdb340] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed77cebb40] [swscaler @ 0x55ed77007f80] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed77cebb40] [swscaler @ 0x55ed77017600] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ed77cebb40] [swscaler @ 0x55ed7709a840] deprecated pixel format used, make sure you did set range correctly
# ...
# Processing frame 478
# Processing frame 547
# Processing frame 548
# Processing frame 479
# Processing frame 480
# Processing frame 549
# frame=  383 fps= 95 q=22.0 size=   16896kB time=00:00:32.40 bitrate=4272.0kbits/s speed=8.01x
# Processing frame 481
# Processing frame 550
# Processing frame 482
# Processing frame 551
# Processing frame 483
# Processing frame 552
# Processing frame 484
# frame=  443 fps= 97 q=22.0 size=   20224kB time=00:00:38.40 bitrate=4314.5kbits/s speed=8.45x
# Processing frame 485
# Processing frame 553
# Processing frame 486
# Processing frame 554
# frame=  447 fps= 92 q=-1.0 Lsize=   22033kB time=00:00:44.40 bitrate=4065.2kbits/s speed= 9.1x
# video:22027kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.027670%
# [libx264 @ 0x55cdb7e3f9c0] frame I:2     Avg QP:19.24  size: 74872
# [libx264 @ 0x55cdb7e3f9c0] frame P:137   Avg QP:20.87  size: 63031
# [libx264 @ 0x55cdb7e3f9c0] frame B:308   Avg QP:22.51  size: 44707
# [libx264 @ 0x55cdb7e3f9c0] consecutive B-frames:  5.6%  3.1% 13.4% 77.9%
# [libx264 @ 0x55cdb7e3f9c0] mb I  I16..4:  3.4% 90.5%  6.1%
# [libx264 @ 0x55cdb7e3f9c0] mb P  I16..4:  1.4% 60.1%  5.1%  P16..4: 10.3% 12.9%  9.4%  0.0%  0.0%    skip: 0.8%
# [libx264 @ 0x55cdb7e3f9c0] mb B  I16..4:  0.8% 20.4%  3.7%  B16..8: 25.1% 24.9%  8.9%  direct: 8.5%  skip: 7.7%  L0:28.6% L1:22.7% BI:48.8%
# [libx264 @ 0x55cdb7e3f9c0] 8x8 transform intra:86.4% inter:80.9%
# [libx264 @ 0x55cdb7e3f9c0] coded y,uvDC,uvAC intra: 89.4% 81.0% 48.8% inter: 67.2% 76.0% 42.5%
# [libx264 @ 0x55cdb7e3f9c0] i16 v,h,dc,p: 19% 61% 10% 10%
# [libx264 @ 0x55cdb7e3f9c0] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 13% 33% 26%  3%  4%  3%  6%  3%  9%
# [libx264 @ 0x55cdb7e3f9c0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 15% 36% 11%  5%  7%  5%  9%  4%  9%
# [libx264 @ 0x55cdb7e3f9c0] i8c dc,h,v,p: 45% 33% 16%  5%
# [libx264 @ 0x55cdb7e3f9c0] Weighted P-Frames: Y:21.9% UV:13.9%
# [libx264 @ 0x55cdb7e3f9c0] ref P L0: 46.7% 23.4% 18.4%  9.9%  1.6%
# [libx264 @ 0x55cdb7e3f9c0] ref B L0: 91.2%  6.9%  1.9%
# [libx264 @ 0x55cdb7e3f9c0] ref B L1: 97.2%  2.8%
# [libx264 @ 0x55cdb7e3f9c0] kb/s:4036.65
# Processing frame 487
# Processing frame 555
# Processing frame 488
# Processing frame 556
# Processing frame 489
# Processing frame 557
# Processing frame 490
# Processing frame 491
# Processing frame 558
# Processing frame 492
# Processing frame 559
# Processing frame 493
# Processing frame 560
# Processing frame 494
# Processing frame 561
# Processing frame 495
# Processing frame 496
# Processing frame 562
# Processing frame 497
# Processing frame 414
# Processing frame 563
# Processing frame 498
# Processing frame 415
# Processing frame 499
# Processing frame 416
# Processing frame 564
# Processing frame 500
# Processing frame 501
# Processing frame 565
# Processing frame 502
# Processing frame 566
# Processing frame 503
# Processing frame 504
# Processing frame 567
# Processing frame 505
# Processing frame 568
# Processing frame 506
# Processing frame 569
# Processing frame 507
# Processing frame 570
# Processing frame 508
# Processing frame 571
# Processing frame 509
# Processing frame 510
# Processing frame 572
# Processing frame 511
# Processing frame 573
# Processing frame 512
# Processing frame 574
# Processing frame 513
# Processing frame 575
# Processing frame 514
# Processing frame 515
# Processing frame 576
# Processing frame 516
# Processing frame 577
# Processing frame 517
# Processing frame Processing frame518
# 578
# Processing frame 519
# Processing frame 579
# Processing frame 520
# Processing frame 580
# Processing frame 521
# Processing frame 522
# Processing frame 523
# Processing frame 417
# Processing frame 418
# Processing frame 524
# Processing frame 419
# Processing frame 525Processing frame
#  420
# Processing frame 421
# Processing frame 526
# Processing frame Processing frame422
# 581
# Processing frame 527
# Processing frame 582
# Processing frame 528
# Processing frame 529
# Processing frame 583
# Processing frame 530
# Processing frame 584
# Processing frame 531
# Processing frame 532
# Processing frame 585
# Processing frame 533
# Processing frame 586
# Processing frame 534
# Processing frame 535
# Processing frame 587
# Processing frame 536
# Processing frame 588
# Processing frame 537
# Processing frame Processing frame589 538
#
# Processing frame 539
# Processing frame 590
# Processing frame 540
# Processing frame 591
# Processing frame 541
# Processing frame 542Processing frame
#  592
# Processing frame 543
# Processing frame 593
# Processing frame 544
# Processing frame 594
# Processing frame 545
# Processing frame 595
# Processing frame 546
# Processing frame 596
# Processing frame 547
# Processing frame 548
# Processing frame 597
# Processing frame 549
# Processing frame 598
# Processing frame 550
# Processing frame 423
# Processing frame 551
# Processing frame 599
# Processing frame 424
# Processing frame 552Processing frame
#  425
# Processing frame 600
# Processing frame 426
# Processing frame 553
# Processing frame 427
# Processing frameProcessing frame  428554
#
# Processing frame 429
# Processing frame 555
# Processing frame 430
# Processing frame 556
# Processing frame 431
# Processing frame 557
